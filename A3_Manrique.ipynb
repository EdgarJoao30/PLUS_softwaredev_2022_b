# %%
import leafmap
import geopandas as gpd

# %%
m = leafmap.Map()
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
shape = gpd.read_file("Limite_departamental/BAS_LIM_DEPARTAMENTO.shp")
shape.head(3)
# Out:
#     NOMBDEP  COUNT FIRST_IDDP     HECTARES  \
# 0  AMAZONAS     84         01  3930646.567
# 1    ANCASH    166         02  3596224.600
# 2  APURIMAC     80         03  2111415.170
#
#                                             geometry
# 0  POLYGON ((212372.284 9332652.146, 212473.276 9...
# 1  POLYGON ((150666.941 9058816.782, 150667.214 9...
# 2  POLYGON ((781311.035 8490376.526, 781314.444 8...

# %%
lima =  shape[shape.NOMBDEP == "LIMA"]
lima
# Out:
#    NOMBDEP  COUNT FIRST_IDDP     HECTARES  \
# 14    LIMA    171         15  3498999.431
#
#                                              geometry
# 14  MULTIPOLYGON (((306343.075 8627544.735, 306321...

# %%
shape.plot(figsize = (6, 6))
# Out:
# <AxesSubplot:>

# %%
lima.plot(figsize = (6, 6))
# Out:
# <AxesSubplot:>
